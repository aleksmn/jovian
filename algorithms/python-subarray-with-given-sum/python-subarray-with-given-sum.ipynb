# %% [markdown]
# # Subarray with Given Sum
#
# The following question was asked during a coding interview for Amazon:
#
# > You are given an array of numbers (non-negative). Find a continuous subarray of the list which adds up to a given sum.
#
#
# ![](https://i.imgur.com/tLEBF7x.png)

# %%
# Solve the problem here

# %%
# Test the solution here

# %%
import jovian

# %%
jovian.commit()
# Out:
# [jovian] Attempting to save notebook..

# %% [markdown]
# ## Solution
#
# Test case:

# %%
arr1 = [1, 7, 4, 2, 1, 3, 11, 5]
target1 = 10

# %% [markdown]
# Brute force $O(n^3)$:

# %%
def subarray_sum1(arr, target):
    n = len(arr)
    for i in range(n):
        for j in range(i, n+1):
            if sum(arr[i:j]) == target:
                return i, j
    return None, None

# %%
i, j = subarray_sum1(arr1, target1)
i, j, arr1[i:j]
# Out:
# (2, 6, [4, 2, 1, 3])

# %% [markdown]
# Better brute force $O(n^2)$:

# %%
def subarray_sum2(arr, target):
    n = len(arr)
    for i in range(n):
        s = 0
        for j in range(i, n+1):
            if s == target:
                return i,j
            s += arr[j]
    return None, None

# %%
i, j = subarray_sum2(arr1, target1)
i, j, arr1[i:j]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-4b424b132be2> in <module>
# ----> 1 i, j = subarray_sum2(arr1, target1)
#       2 i, j, arr1[i:j]
#
# <ipython-input-6-86a15ddd810a> in subarray_sum2(arr, target)
#       6             if s == target:
#       7                 return i,j
# ----> 8             s += arr[j]
#       9     return None, None
#
# IndexError: list index out of range

# %% [markdown]
# Greedy algorithm $O(n)$:

# %%
def subarray_sum3(arr, target):
    n = len(arr)
    i, j, s = 0, 0, 0
    while i < n and j <= n:
        if s == target:
            return i, j
        elif s < target:
            s += arr[j]
            j += 1
        elif s > target:
            s -= arr[i]
            i += 1
    return None, None

# %%
i, j = subarray_sum3(arr1, target1)
i, j, arr1[i:j]
# Out:
# (2, 6, [4, 2, 1, 3])
